# %% [markdown]
# Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
import requests, pandas as pd, json
####get citybikes dataframe###########################################
response = requests.get('http://api.citybik.es/v2/networks')
data = response.json()
#nested dictionary structure, look for specific city in this case Paris because the documentation used it as an example
def get_citybikes_by_city(city):
    """
    this is my functiont that takes a string city name as a paremeter and returns a dataframe of the nearby citybikes
    """
    response = requests.get(f"http://api.citybik.es/v2/networks/velib")
    jsonobject = response.json()
    stations = jsonobject['network']['stations']
    df = pd.DataFrame(stations)
    return df

df = get_citybikes_by_city("Paris")

#normalize the object['extra'] column
df_extra = pd.json_normalize(df['extra'])
df = pd.concat([df, df_extra], axis=1)
df.drop('extra', axis=1, inplace=True)

print(df.head())
#################get foursquare dataframe#############################


#using paris as an example 
lattitude = 48.8588548
longitude = 2.347035

def get_json_by_ll(lattitude,longitude):
    """
    this function takes two integers as input, lattitude adn longitude.
    it returns a json object to convert to dataframe
    """
    #construct the url witht he requests library functions
    url = "https://api.foursquare.com/v3/places/search"
    params = {
        "ll": str(lattitude)+","+str(longitude),
        "radius": 1000,
        "fields": "categories,rating,geocodes,categories,location,name,fsq_id,stats,price",
        "limit": 50
    }
    headers = {
        "accept": "application/json",
        "Authorization": "fsq3aB5c7PNhhqT23DewFyJ7Easfex4oG/ymaLVxSui+7VE="
    }
    
    response = requests.get(url, params=params, headers=headers)
    data = response.json()
    ratings = [place.get('rating', 0) for place in data.get('results', [])]
    return data
response = get_json_by_ll(lattitude,longitude)

def get_fs_data(jsonresponse):
    """
    this is a function that takes the json response and uses getter functions on the data structure 
    to return required details, it returns a list of details to be used in a dataframe
    """
    poi_details = [] # POI - point of interest 
    for poi in response.get('results', []):
        idd = poi.get('fsq_id', 0)
        name = poi.get('name', 'no data')
        rating = poi.get('rating', 0)
        location = poi.get('location', {}).get('formatted_address', 'no data')
        categories = poi.get('categories','no data')
        poi_info = {
            "id": idd,
            "name": name,
            "rating": rating,
            "location": location,
        }


        poi_details.append(poi_info)
    return poi_details
list_of_stuff = get_fs_data(response)
# Create DataFrame
df1 = pd.DataFrame(list_of_stuff)

# Print the DataFrame
print(df1)
########get the yelp data##########################################################################
def yelp_json_by_name(name):
    API_KEY = "V6RfSQbnmYuJu5EBRgRikoCk-ScXUU38_M1rKj4CxeKGqmL0nGd1iLhkloqMVAsUK7uYrlpyE4OrIDRIrNO5lEPo60qcEEitGxX7tNBr8hRNu4RTHSKV_IztV2h7ZHYx"
    BASE_URL = "https://api.yelp.com/v3"
    term = "bike stations"
    location = name
    headers = {
        "Authorization": f"Bearer {API_KEY}"
    }
    params = {
        "term": term,
        "location": location,
        "radius": 1000
    }
    url = f"{BASE_URL}/businesses/search"
    response = requests.get(url, headers=headers, params=params)
    return response.json()
data = yelp_json_by_name("Paris")

def get_yelp_data(json):   
    names = []
    ratings = []
    addresses = []
    phones = []
    
    for business in json['businesses']:
        names.append(business['name'])
        ratings.append(business.get('rating', 0))
        addresses.append(', '.join(business['location']['display_address']))
        phones.append(business.get('phone', 'no data'))
        
    data_dict = {
        'names': names,
        'ratings': ratings,
        'addresses': addresses,
        'phones': phones
    }
    
    return data_dict

result = get_yelp_data(data)

dictionary_to_use = get_yelp_data(data)
df2 = pd.DataFrame({
    'name': dictionary_to_use['names'],
    'rating': dictionary_to_use['ratings'],
    'addresses': dictionary_to_use['addresses'],
    'phone': dictionary_to_use['phones']
})
print(df2)

##########Concatenate the dataframes####################################################################
combined_df = pd.concat([df1, df2], ignore_index=True)

# combine df with combined_df
final_df = pd.concat([df, combined_df], ignore_index=True)


print(final_df)
# Out:
#    empty_slots  free_bikes                                id   latitude  \
# 0           31           4  78ec9186acd18a0b30bd3156d24b9f8d  48.865983
# 1           34          17  43c856353b954711f2bbee185a1f9d04  48.853756
# 2           14          24  9b2700f3b19beb1dd9df2fd6a013789f  48.867872
# 3           18           2  80778031e1a033712bfc3a27a190d5dd  48.856452
# 4           18           3  f8f9ec30d28856f9b7fad103be9e4674  48.879296
#
#    longitude                                name                    timestamp  \
# 0   2.275725       Benjamin Godard - Victor Hugo  2023-06-05T19:07:49.214000Z
# 1   2.339096  André Mazet - Saint-André des Arts  2023-06-05T19:07:49.187000Z
# 2   2.364898     Faubourg Du Temple - Republique  2023-06-05T19:07:48.245000Z
# 3   2.334852              Beaux-Arts - Bonaparte  2023-06-05T19:07:48.514000Z
# 4   2.337360                  Toudouze - Clauzel  2023-06-05T19:07:48.587000Z
#
#    banking  ebikes  last_updated  payment-terminal  renting  returning  slots  \
# 0    False       4    1685989375             False        1          1     35
# 1     True       3    1685989904              True        1          1     55
# 2     True       0    1685989901              True        1          1     38
# 3     True       1    1685989698              True        1          1     20
# 4     True       2    1685989533              True        1          1     21
#
#    station_id    uid       payment
# 0   213688169  16107           NaN
# 1    99950133   6015  [creditcard]
# 2   312165511  11037  [creditcard]
# 3   210405211   6021  [creditcard]
# 4       36255   9020  [creditcard]
#                           id  \
# 0   4b27effef964a5209a8c24e3
# 1   4e0766702271dfa46baee474
# 2   4d71280e1529a143391197a0
# 3   4b8ebd9df964a5203c3433e3
# 4   4adcda08f964a520ab3321e3
# 5   4b5c7d1ff964a5205f3229e3
# 6   540063e9498e81e53bf4f527
# 7   4dbd336b6a23e294ba405cfa
# 8   4b9bf8ebf964a520253c36e3
# 9   54351b59498e123ee4afc7ff
# 10  519a24a8498e55ea1824b30a
# 11  4d79108e0ddba35dfac24a76
# 12  57035c8b498ebcbc85d70c40
# 13  4c862093e602b1f71304bd7a
# 14  4bf41231e5eba59334341f90
# 15  4b1fe208f964a520362a24e3
# 16  4adcda09f964a520eb3321e3
# 17  5113ebbce4b0d3c1022aef14
# 18  58728968d4ab735c99ae0c5e
# 19  52b5c225498eeda0297a855a
# 20  4f979c8ae4b05465dae0714f
# 21  4adcda11f964a520d33521e3
# 22  4adcda05f964a5206c3221e3
# 23  58e0f18f561ded7abcbbbd01
# 24  51cfcf55498e81b280cea40e
# 25  4b533b45f964a520509327e3
# 26  4adcda0cf964a520c03421e3
# 27  512534ece4b03a94f9a50313
# 28  4b6bebdaf964a520a31c2ce3
# 29  600af5ddd49d6e3b5b1abf05
# 30  58d800df9435a979b8a645fa
# 31  5b81a899249623002cbde2b3
# 32  4adcda22f964a5201c3a21e3
# 33  4bc8dd13b6c49c748f438d91
# 34  560d03b5498eaea729b6bf10
# 35  53568d3e498e92e5a3a56f36
# 36  4b4b6fe4f964a520a19b26e3
# 37  59247f4e0d2be70573edd834
# 38  4c0bc2fdbbc676b018f64bd5
# 39  4c00046cc30a2d7fbeda111d
# 40  578a2e9f498e1129b45bb0db
# 41  5a1c229bc0af5707fb3601cd
# 42  4adcda0ef964a520353521e3
# 43  4c079d740ed3c928b6be797d
# 44  4b33781ef964a520ad1925e3
# 45  5540b49d498e84ce71f6b0ce
# 46  4c4af766c668e21e3e4565f9
# 47  59a1833193bd63511bd5629d
# 48  4b530766f964a520f88c27e3
# 49  56c39299498e0190d29569ef
#
#                                                  name  rating  \
# 0                                   Au Vieux Comptoir     8.9
# 1                                              Rivoli     9.1
# 2                                       Bières Cultes     8.7
# 3                                 Théâtre du Châtelet     8.9
# 4                                    Duc des Lombards     8.6
# 5            Saint-Jacques Tower (Tour Saint-Jacques)     8.7
# 6                                La Barbière de Paris     8.8
# 7                     Square de la tour Saint-Jacques     8.6
# 8                                     La Tavola Calda     8.7
# 9                                          L'Alsacien     8.7
# 10              Tour de lHorloge du Palais de la Cité     8.6
# 11                                     Sergeant Paper     8.8
# 12                                         Lego Store     8.9
# 13                                 Boulangerie Julien     8.6
# 14                          Place de l'Hôtel-de-Ville     9.2
# 15                                    Enza & Famiglia     8.6
# 16                                     Place Dauphine     9.3
# 17                                 Le Centre Pompidou     9.2
# 18                                       Glace BACHIR     9.0
# 19                                      Coffee Crêpes     8.8
# 20                                    Place du Louvre     9.3
# 21                                   Atelier Brancusi     8.5
# 22                                          Le Fumoir     8.8
# 23                                Parc Rives de Seine     8.6
# 24                                            Huygens     8.7
# 25                                              Fleux     9.3
# 26                              Square du Vert-Galant     8.5
# 27                                   Comptoir Gourmet     9.0
# 28                                             Pralus     9.0
# 29            Bourse de Commerce – Pinault Collection     8.9
# 30                      Berges de Seine – Rive droite     8.8
# 31                                            Amorino     8.7
# 32                                           Spa Nuxe     8.9
# 33                                  Pain Vin Fromages     8.8
# 34  Trois Fois Plus de Piment (Trois Fois plus de ...     8.8
# 35                                          Chez Nous     9.1
# 36                                 Ze Kitchen Galerie     8.8
# 37                                       Maison Aleph     9.0
# 38                             Galerie Azzedine Alaïa     9.1
# 39             Parvis Notre-Dame — Place Jean-Paul II     9.0
# 40                                       Shiso Burger     9.0
# 41                                             Bo&Mie     8.9
# 42                                   Monnaie de Paris     8.8
# 43                                        Cour Carrée     9.5
# 44                                      E. Dehillerin     8.7
# 45                               Restaurant Guy Savoy     8.7
# 46                                Christian Louboutin     8.6
# 47                                     Terres de Café     9.0
# 48                                 Place Saint-Michel     9.1
# 49                                  La Maison du Saké     8.9
#
#                                              location
# 0   17 rue Lavandieres Staine Opportune proche de ...
# 1   28 rue de Rivoli (Rue des Déchargeurs), 75004 ...
# 2                      14 rue des Halles, 75001 Paris
# 3               1 place du Châtelet, 1er, 75001 Paris
# 4   42 rue des Lombards (Boulevard de Sébastopol),...
# 5                       88 rue de Rivoli, 75004 Paris
# 6                    7 rue Bertin Poirée, 75001 Paris
# 7                       88 rue de Rivoli, 75001 Paris
# 8                 39 rue des Bourdonnais, 75001 Paris
# 9                        6 rue Saint Bon, 75004 Paris
# 10  boulevard du Palais (Quai de l'Horloge), 75001...
# 11                    38 rue Quincampoix, 75004 Paris
# 12  1 Passage Canopee (Forum des Halles), 75001 Paris
# 13                   75 rue Saint-Honoré, 75001 Paris
# 14             place de l'Hôtel de Ville, 75004 Paris
# 15                 89 rue St-Honoré, 1er, 75001 Paris
# 16                      1 place Dauphine, 75001 Paris
# 17                place Georges-Pompidou, 75004 Paris
# 18                      rue Rambuteau 58, 75004 Paris
# 19                     24 quai du Louvre, 75001 Paris
# 20                       place du Louvre, 75001 Paris
# 21               Centre Georges Pompidou, 75004 Paris
# 22     6 rue de l’Amiral de Coligny, 1er, 75001 Paris
# 23                        Quais de Seine, 75000 Paris
# 24  24 rue du Temple (Rue Sainte Croix De La Breto...
# 25  39 / 43 / 52 rue Sainte Croix de la Bretonneri...
# 26                 15 place du Pont Neuf, 75001 Paris
# 27  51 rue du Temple (Rue des Blancs-Manteaux), 75...
# 28                      35 rue Rambuteau, 75004 Paris
# 29                      2 rue de Viarmes, 75001 Paris
# 30  de la passerelle Léopold-Sédar-Senghor au port...
# 31                 13 rue d'Arcole Paris, 75004 Paris
# 32                 32-34 rue Montorgueil, 75001 Paris
# 33           3 rue de Geoffroy l'Angevin, 75004 Paris
# 34   184 rue Saint-Martin (Rue aux Ours), 75003 Paris
# 35                 10 rue Dauphine 75006, 75006 Paris
# 36        4 rue des Grands Augustins, 6e, 75006 Paris
# 37                 20 rue de la Verrerie, 75004 Paris
# 38                 18 rue de la Verrerie, 75003 Paris
# 39  place du Parvis-Notre-Dame (Place Jean-Paul II...
# 40                  21 quai Saint Michel, 75005 Paris
# 41                     18 rue de Turbigo, 75002 Paris
# 42                  11 quai de Conti, 6e, 75006 Paris
# 43     Musée du Louvre (Place du Louvre), 75001 Paris
# 44            18-20 rue Coquillière, 1er, 75001 Paris
# 45  11 quai de Conti, 6e (Monnaie de Paris), 75006...
# 46     19 rue Jean-Jacques Rousseau, 1er, 75001 Paris
# 47                      14 rue Rambuteau, 75003 Paris
# 48                 24 boul. Saint Michel, 75006 Paris
# 49                     11 rue Tiquetonne, 75002 Paris
#               name  rating                                addresses  \
# 0        Allo Vélo     4.0    2 rue Beauregard, 75002 Paris, France
# 1   Fat Tire Tours     4.5  24 rue Edgar Faure, 75015 Paris, France
# 2  Blue Fox Travel     5.0                      75004 Paris, France
#
#           phone
# 0  +33140353636
# 1  +33182888096
# 2  +33649323649
#       empty_slots  free_bikes                                id   latitude  \
# 0            31.0         4.0  78ec9186acd18a0b30bd3156d24b9f8d  48.865983
# 1            34.0        17.0  43c856353b954711f2bbee185a1f9d04  48.853756
# 2            14.0        24.0  9b2700f3b19beb1dd9df2fd6a013789f  48.867872
# 3            18.0         2.0  80778031e1a033712bfc3a27a190d5dd  48.856452
# 4            18.0         3.0  f8f9ec30d28856f9b7fad103be9e4674  48.879296
# ...           ...         ...                               ...        ...
# 1497          NaN         NaN          4b530766f964a520f88c27e3        NaN
# 1498          NaN         NaN          56c39299498e0190d29569ef        NaN
# 1499          NaN         NaN                               NaN        NaN
# 1500          NaN         NaN                               NaN        NaN
# 1501          NaN         NaN                               NaN        NaN
#
#       longitude                                name  \
# 0      2.275725       Benjamin Godard - Victor Hugo
# 1      2.339096  André Mazet - Saint-André des Arts
# 2      2.364898     Faubourg Du Temple - Republique
# 3      2.334852              Beaux-Arts - Bonaparte
# 4      2.337360                  Toudouze - Clauzel
# ...         ...                                 ...
# 1497        NaN                  Place Saint-Michel
# 1498        NaN                   La Maison du Saké
# 1499        NaN                           Allo Vélo
# 1500        NaN                      Fat Tire Tours
# 1501        NaN                     Blue Fox Travel
#
#                         timestamp banking  ebikes  last_updated  ... renting  \
# 0     2023-06-05T19:07:49.214000Z   False     4.0  1.685989e+09  ...     1.0
# 1     2023-06-05T19:07:49.187000Z    True     3.0  1.685990e+09  ...     1.0
# 2     2023-06-05T19:07:48.245000Z    True     0.0  1.685990e+09  ...     1.0
# 3     2023-06-05T19:07:48.514000Z    True     1.0  1.685990e+09  ...     1.0
# 4     2023-06-05T19:07:48.587000Z    True     2.0  1.685990e+09  ...     1.0
# ...                           ...     ...     ...           ...  ...     ...
# 1497                          NaN     NaN     NaN           NaN  ...     NaN
# 1498                          NaN     NaN     NaN           NaN  ...     NaN
# 1499                          NaN     NaN     NaN           NaN  ...     NaN
# 1500                          NaN     NaN     NaN           NaN  ...     NaN
# 1501                          NaN     NaN     NaN           NaN  ...     NaN
#
#       returning  slots   station_id    uid       payment rating  \
# 0           1.0   35.0  213688169.0  16107           NaN    NaN
# 1           1.0   55.0   99950133.0   6015  [creditcard]    NaN
# 2           1.0   38.0  312165511.0  11037  [creditcard]    NaN
# 3           1.0   20.0  210405211.0   6021  [creditcard]    NaN
# 4           1.0   21.0      36255.0   9020  [creditcard]    NaN
# ...         ...    ...          ...    ...           ...    ...
# 1497        NaN    NaN          NaN    NaN           NaN    9.1
# 1498        NaN    NaN          NaN    NaN           NaN    8.9
# 1499        NaN    NaN          NaN    NaN           NaN    4.0
# 1500        NaN    NaN          NaN    NaN           NaN    4.5
# 1501        NaN    NaN          NaN    NaN           NaN    5.0
#
#                                 location  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 1497  24 boul. Saint Michel, 75006 Paris
# 1498      11 rue Tiquetonne, 75002 Paris
# 1499                                 NaN
# 1500                                 NaN
# 1501                                 NaN
#
#                                     addresses         phone
# 0                                         NaN           NaN
# 1                                         NaN           NaN
# 2                                         NaN           NaN
# 3                                         NaN           NaN
# 4                                         NaN           NaN
# ...                                       ...           ...
# 1497                                      NaN           NaN
# 1498                                      NaN           NaN
# 1499    2 rue Beauregard, 75002 Paris, France  +33140353636
# 1500  24 rue Edgar Faure, 75015 Paris, France  +33182888096
# 1501                      75004 Paris, France  +33649323649
#
# [1502 rows x 21 columns]
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_9332\3413857137.py:141: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   print(final_df)

# %%
print(final_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   empty_slots       1449 non-null   float64
#  1   free_bikes        1449 non-null   float64
#  2   id                1499 non-null   object
#  3   latitude          1449 non-null   float64
#  4   longitude         1449 non-null   float64
#  5   name              1502 non-null   object
#  6   timestamp         1449 non-null   object
#  7   banking           1449 non-null   object
#  8   ebikes            1449 non-null   float64
#  9   last_updated      1449 non-null   float64
#  10  payment-terminal  1449 non-null   object
#  11  renting           1449 non-null   float64
#  12  returning         1449 non-null   float64
#  13  slots             1449 non-null   float64
#  14  station_id        1449 non-null   float64
#  15  uid               1449 non-null   object
#  16  payment           840 non-null    object
#  17  rating            53 non-null     float64
#  18  location          50 non-null     object
#  19  addresses         3 non-null      object
#  20  phone             3 non-null      object
# dtypes: float64(11), object(10)
# memory usage: 246.5+ KB
# None

# %% [markdown]
# Provide a visualization that you used as part of your EDA process. Explain the initial pattern or relationship you discoved through this visualization.

# %%
import matplotlib.pyplot as plt

# Get numeric column names
numeric_columns = final_df.select_dtypes(include='number').columns

# Plot histograms
for column in numeric_columns:
    plt.hist(final_df[column].dropna(), bins=20)
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()


#lattitude and longitude are close to normal distribution so they should be pretty random.
#the other data is skewed so if outliers cant be found using EDA i should apply an appropraite algorithm to account for that

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
import sqlite3
import pandas as pd
import numpy as np


conn = sqlite3.connect(r'C:\Users\Jacob\statistical_modelling-_with_python\data\results.db')

#select columns to add
convert_df = final_df[['free_bikes', 'latitude', 'longitude']]

#clean values in free bikes
convert_df['free_bikes'] = convert_df['free_bikes'].replace([np.inf, -np.inf], np.nan).fillna(0).astype(int)

#convert long and lat to float
convert_df['latitude'] = convert_df['latitude'].astype(float)
convert_df['longitude'] = convert_df['longitude'].astype(float)

# reaplace nones with supported null type
convert_df = convert_df.where(pd.notnull(convert_df), None)

#create the frame
convert_df.to_sql('mytable', conn, if_exists='replace', index=False)

# Close the connection
conn.close()
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_9332\3488611537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   convert_df['free_bikes'] = convert_df['free_bikes'].replace([np.inf, -np.inf], np.nan).fillna(0).astype(int)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_9332\3488611537.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   convert_df['latitude'] = convert_df['latitude'].astype(float)
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_9332\3488611537.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   convert_df['longitude'] = convert_df['longitude'].astype(float)

# %% [markdown]
# Look at the data before and after the join to validate your data.
